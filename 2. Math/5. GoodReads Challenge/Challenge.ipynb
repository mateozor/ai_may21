# %%
import pandas as pd

df = pd.read_csv("Dataset.csv")

# %%
df.sample(10)
# Out:
#      Unnamed: 0                                                url  \
# 574         574  https://www.goodreads.com/book/show/52783.Hend...
# 441         441  https://www.goodreads.com/book/show/63033.The_...
# 82           82  https://www.goodreads.com/book/show/320.One_Hu...
# 3             3  https://www.goodreads.com/book/show/4671.The_G...
# 238         238  https://www.goodreads.com/book/show/682804.The...
# 346         346  https://www.goodreads.com/book/show/80176.Wine...
# 444         444  https://www.goodreads.com/book/show/40189.A_Ye...
# 484         484  https://www.goodreads.com/book/show/7061.The_N...
# 95           95  https://www.goodreads.com/book/show/33574273-a...
# 224         224    https://www.goodreads.com/book/show/38709.Holes
#
#                                   title  \
# 574             Henderson the Rain King
# 441               The Savage Detectives
# 82        One Hundred Years of Solitude
# 3                      The Great Gatsby
# 238                   The Killer Angels
# 346                     Winesburg, Ohio
# 444                  A Year in Provence
# 484  The No. 1 Ladies' Detective Agency
# 95                    A Wrinkle in Time
# 224                               Holes
#
#                                         author  num_reviews  num_ratings  \
# 574                              Saul Bellow,           834        14156
# 441                           Roberto Bolaño,          3548        34270
# 82                    Gabriel García Márquez,         32653       788288
# 3                        F. Scott Fitzgerald,         71655      3980916
# 238                             Michael Shaara         4894        77102
# 346                          Sherwood Anderson         2370        30831
# 444                                Peter Mayle         3218        66197
# 484  Alexander McCall Smith (Goodreads Author)        11660       239519
# 95                           Madeleine L'Engle        34713      1081512
# 224            Louis Sachar (Goodreads Author)        21243      1012216
#
#      avg_rating  num_pages  original_publish_year  series  \
# 574        3.78        341                   1959   False
# 441        4.14        577                   1998   False
# 82         4.09        417                   1967   False
# 3          3.93        200                   1925   False
# 238        4.31        345                   1974    True
# 346        3.84        240                   1919   False
# 444        3.97        207                   1989    True
# 484        3.79        235                   1998    True
# 95         3.99        218                   1962    True
# 224        3.98        233                   1998    True
#
#                                               genres  \
# 574            ['Fiction', 'Classics', 'Literature']
# 441                ['Fiction', 'Novels', 'Cultural']
# 82        ['Fiction', 'Classics', 'Magical Realism']
# 3                ['Classics', 'Fiction', 'Academic']
# 238  ['Historical', 'Historical Fiction', 'Fiction']
# 346         ['Fiction', 'Classics', 'Short Stories']
# 444        ['Travel', 'Nonfiction', 'Autobiography']
# 484               ['Mystery', 'Fiction', 'Cultural']
# 95                ['Fantasy', 'Fiction', 'Classics']
# 224          ['Young Adult', 'Fiction', 'Childrens']
#
#                                                 awards         places  \
# 574    National Book Award Finalist for Fiction (1960)            NaN
# 441  Premio Herralde de Novela (1998), Premio Inter...         Mexico
# 82   Premio Internacional de Novela Rómulo Gallegos...            NaN
# 3    Grammy Award Nominee for Best Spoken Word Albu...  United States
# 238                  Pulitzer Prize for Fiction (1975)  United States
# 346                Premi Llibreter de narrativa (2009)  United States
# 444  Prix des libraires du Québec for Lauréats hors...            NaN
# 484                           Martin Beck Award (2004)   South Africa
# 95   Newbery Medal (1963), Dorothy Canfield Fisher ...  United States
# 224  Newbery Medal (1999), National Book Award for ...  United States
#
#      awards_count
# 574             1
# 441             4
# 82              2
# 3               2
# 238             1
# 346             1
# 444             1
# 484             1
# 95              4
# 224            21

# %%
df.dtypes
# Out:
# Unnamed: 0                 int64
# url                       object
# title                     object
# author                    object
# num_reviews                int64
# num_ratings                int64
# avg_rating               float64
# num_pages                  int64
# original_publish_year      int64
# series                      bool
# genres                    object
# awards                    object
# places                    object
# awards_count               int64
# dtype: object

# %%
df["minmax_norm_ratings"] = (1 + ((df["avg_rating"]-df["avg_rating"].min())/(df["avg_rating"].max()-df["avg_rating"].min()))*9).round(2)
df.sample(10)
# Out:
#      Unnamed: 0                                                url  \
# 509         509  https://www.goodreads.com/book/show/8248.By_th...
# 170         170  https://www.goodreads.com/book/show/960.Angels...
# 393         393  https://www.goodreads.com/book/show/586472.The...
# 450         450  https://www.goodreads.com/book/show/77287.Inde...
# 445         445  https://www.goodreads.com/book/show/7742.Ahab_...
# 441         441  https://www.goodreads.com/book/show/63033.The_...
# 567         567  https://www.goodreads.com/book/show/77773.To_S...
# 524         524  https://www.goodreads.com/book/show/14185.The_...
# 495         495  https://www.goodreads.com/book/show/77554.The_...
# 94           94  https://www.goodreads.com/book/show/24178.Char...
#
#                                      title                        author  \
# 509           By the Shores of Silver Lake        Laura Ingalls Wilder,
# 170                        Angels & Demons  Dan Brown (Goodreads Author)
# 393                        The Right Stuff                     Tom Wolfe
# 450                     Independent People             Halldór Laxness,
# 445         Ahab's Wife, or The Star-Gazer            Sena Jeter Naslund
# 441                  The Savage Detectives              Roberto Bolaño,
# 567              To Say Nothing of the Dog                 Connie Willis
# 524  The Three Stigmata of Palmer Eldritch                Philip K. Dick
# 495                      The Stone Diaries                 Carol Shields
# 94                         Charlotte's Web                  E.B. White,
#
#      num_reviews  num_ratings  avg_rating  num_pages  original_publish_year  \
# 509         1364        71447        4.16        357                   1939
# 170        29859      2780338        3.91        736                   2000
# 393         1700        47243        4.22        352                   1979
# 450         1312         9478        4.17        482                   1934
# 445         2726        43116        4.03        704                   1999
# 441         3548        34270        4.14        577                   1998
# 567         4002        35088        4.12        512                   1998
# 524         1660        32963        4.01        231                   1965
# 495         1892        36911        3.87        361                   1993
# 94         19013      1492814        4.17        184                   1952
#
#      series                                             genres  \
# 509    True   ['Classics', 'Historical', 'Historical Fiction']
# 170    True                 ['Fiction', 'Mystery', 'Thriller']
# 393   False               ['Nonfiction', 'History', 'Science']
# 450    True              ['Fiction', 'Classics', 'Historical']
# 445   False    ['Fiction', 'Historical', 'Historical Fiction']
# 441   False                  ['Fiction', 'Novels', 'Cultural']
# 567    True  ['Science Fiction', 'Science Fiction', 'Time T...
# 524   False  ['Science Fiction', 'Fiction', 'Science Fictio...
# 495   False                  ['Fiction', 'Cultural', 'Canada']
# 94    False               ['Classics', 'Childrens', 'Fiction']
#
#                                                 awards         places  \
# 509  Newbery Medal Nominee (1940), Pacific Northwes...  United States
# 170                    Humo's Gouden Bladwijzer (2005)          Italy
# 393  National Book Award for General Nonfiction (Ha...            NaN
# 450        Premi Llibreter de narrativa Nominee (2005)            NaN
# 445  Orange Prize Nominee for Fiction Longlist (200...            NaN
# 441  Premio Herralde de Novela (1998), Premio Inter...         Mexico
# 567  Hugo Award for Best Novel (1999), Nebula Award...            NaN
# 524         Nebula Award Nominee for Best Novel (1965)            NaN
# 495  Booker Prize Nominee (1993), Pulitzer Prize fo...  United States
# 94   Newbery Medal Nominee (1953), George C. Stone ...            NaN
#
#      awards_count  minmax_norm_ratings
# 509             3                 6.42
# 170             1                 4.23
# 393             3                 6.94
# 450             1                 6.50
# 445             3                 5.28
# 441             4                 6.24
# 567             6                 6.07
# 524             1                 5.11
# 495             5                 3.88
# 94              5                 6.50

# %%
df.to_csv("groupChallenge.csv", index = True)
